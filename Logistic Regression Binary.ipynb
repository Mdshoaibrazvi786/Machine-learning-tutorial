# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\mr.shoaib\Downloads\car_ownership.csv")

# %%
df.head(5)
# Out:
#    monthly_salary  owns_car
# 0           22000         0
# 1           25000         0
# 2           47000         1
# 3           52000         0
# 4           46000         1

# %%
plt.scatter(df['monthly_salary'],df['owns_car'])
plt.show()

# %%
x = df[['monthly_salary']]
y = df['owns_car']

# %%
x
# Out:
#     monthly_salary
# 0            22000
# 1            25000
# 2            47000
# 3            52000
# 4            46000
# 5            56000
# 6            55000
# 7            60000
# 8            62000
# 9            61000
# 10           18000
# 11           28000
# 12           27000
# 13           29000
# 14           49000
# 15           55000
# 16           25000
# 17           58000
# 18           19000
# 19           18000
# 20           21000
# 21           26000
# 22           40000
# 23           45000
# 24           50000
# 25           54000
# 26           23000

# %%
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     1
# 6     0
# 7     1
# 8     1
# 9     1
# 10    0
# 11    0
# 12    0
# 13    0
# 14    1
# 15    1
# 16    1
# 17    1
# 18    0
# 19    0
# 20    0
# 21    0
# 22    1
# 23    1
# 24    1
# 25    1
# 26    0
# Name: owns_car, dtype: int64

# %%
x_train,x_test,y_train,y_train = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression() 
lr.fit(x,y)
# Out:
# LogisticRegression()

# %%
lr.score(x,y)*100
# Out:
# 88.88888888888889

# %%
lr.coef_
# Out:
# array([[0.00013572]])

# %%
lr.intercept_
# Out:
# array([-5.27293146])

# %%
lr.predict([[22000]])
# Out:
# array([0], dtype=int64)

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x='monthly_salary',y='owns_car',data=df)
sns.lineplot(x='monthly_salary',y=lr.predict(x),data=df)
plt.show()
