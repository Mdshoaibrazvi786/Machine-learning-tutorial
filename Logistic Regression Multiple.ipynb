# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings('ignore')

# %%
df =  pd.read_csv(r"C:\Users\mr.shoaib\Downloads\placed.csv")

# %%
df
# Out:
#     cgpa  scores  placed
# 0    4.4      20       0
# 1    9.6      90       0
# 2    7.6      58       0
# 3    6.4      31       0
# 4    2.4       5       0
# ..   ...     ...     ...
# 95   5.4      26       1
# 96   5.7      32       1
# 97   4.8      25       1
# 98   1.2       3       0
# 99   2.0       8       0
#
# [100 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# cgpa      0
# scores    0
# placed    0
# dtype: int64

# %%
df.describe()
# Out:
#              cgpa      scores      placed
# count  100.000000  100.000000  100.000000
# mean     5.233000   34.510000    0.480000
# std      2.681438   29.167401    0.502117
# min      1.000000    0.000000    0.000000
# 25%      2.775000   10.000000    0.000000
# 50%      5.150000   25.000000    0.000000
# 75%      7.600000   59.000000    1.000000
# max      9.900000  100.000000    1.000000

# %%
plt.scatter(df['cgpa'],df['scores'])
plt.show()

# %%
x = df.iloc[:,:-1]
y = df['placed']

# %%
x
# Out:
#     cgpa  scores
# 0    4.4      20
# 1    9.6      90
# 2    7.6      58
# 3    6.4      31
# 4    2.4       5
# ..   ...     ...
# 95   5.4      26
# 96   5.7      32
# 97   4.8      25
# 98   1.2       3
# 99   2.0       8
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 95    1
# 96    1
# 97    1
# 98    0
# 99    0
# Name: placed, Length: 100, dtype: int64

# %%
x_train,x_test,y_train,y_train = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression() 
lr.fit(x,y)
# Out:
# LogisticRegression()

# %%
lr.score(x,y)*100
# Out:
# 57.99999999999999

# %%
lr.coef_
# Out:
# array([[ 0.18925853, -0.01020883]])

# %%
lr.intercept_
# Out:
# array([-0.71982504])

# %%
lr.predict([[4.4, 20]])
# Out:
# array([0], dtype=int64)

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x='cgpa',y='scores',data=df)
sns.lineplot(x='cgpa',y=lr.predict(x),data=df)
plt.show()
