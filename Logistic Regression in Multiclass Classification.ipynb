# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings('ignore')

# %%
df =  pd.read_excel(r"C:\Users\mr.shoaib\Documents\iris.xlsx")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal-width  species
# 0           5.1          3.5           1.4          0.2  species
# 1           6.1          4.5           2.4          1.2  species
# 2           7.1          5.5           3.4          2.2  species
# 3           8.1          6.5           4.4          3.2  species
# 4           9.1          7.5           5.4          4.2  species

# %%
df['species'].unique()
# Out:
# array(['species', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(data=df,hue='species')
plt.show()

# %%
x = df.iloc[:,:-1]
y = df['species']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %% [markdown]
# OVR Method

# %%
lr = LogisticRegression(multi_class="ovr")
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(multi_class='ovr')

# %%
lr.score(x_test,y_test)*100
# Out:
# 60.0

# %% [markdown]
# Multinomial (isko hum bolte hai Softmax method).

# %%
lm = LogisticRegression(multi_class="multinomial")
lm.fit(x_train,y_train)
# Out:
# LogisticRegression(multi_class='multinomial')

# %%
lm.score(x_test,y_test)*100
# Out:
# 60.0
