# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
af=pd.read_csv(r"C:\Users\mr.shoaib\Downloads\Salary_Data.csv")

# %%
af.head(5)
# Out:
#    Age  YearsExperience  Salary
# 0   21                1   39343
# 1   21                3   46205
# 2   21                5   37731
# 3   22                2   43525
# 4   22                2   39891

# %%
af.isnull().sum()
# Out:
# Age                0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
af.shape
# Out:
# (30, 3)

# %%
sns.pairplot(data=af)
plt.show()

# %%
sns.heatmap(data=af.corr(),annot=True)
plt.show()

# %%
len(x), len(y)
# Out:
# (30, 30)

# %%
x.shape
# Out:
# (30, 2)

# %%
y.shape
# Out:
# (30,)

# %%
#Input and output Alag.

# %%
x = af.iloc[:,:-1]

# %%
x
# Out:
#     Age  YearsExperience
# 0    21                1
# 1    21                3
# 2    21                5
# 3    22                2
# 4    22                2
# 5    23                9
# 6    23                3
# 7    23                2
# 8    23                2
# 9    23                7
# 10   23                9
# 11   24                4
# 12   24                4
# 13   24                1
# 14   25                5
# 15   25                9
# 16   26                1
# 17   27                3
# 18   28                9
# 19   29                6
# 20   30                8
# 21   30                1
# 22   31                9
# 23   32                2
# 24   33                7
# 25   34                9
# 26   35                5
# 27   36                3
# 28   37                3
# 29   38                5

# %%
x = af.iloc[:,:-1]
y = af['Salary']

# %%
af.shape
# Out:
# (30, 3)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.5,random_state=42)

# %%
x
# Out:
#     Age  YearsExperience
# 0    21                1
# 1    21                3
# 2    21                5
# 3    22                2
# 4    22                2
# 5    23                9
# 6    23                3
# 7    23                2
# 8    23                2
# 9    23                7
# 10   23                9
# 11   24                4
# 12   24                4
# 13   24                1
# 14   25                5
# 15   25                9
# 16   26                1
# 17   27                3
# 18   28                9
# 19   29                6
# 20   30                8
# 21   30                1
# 22   31                9
# 23   32                2
# 24   33                7
# 25   34                9
# 26   35                5
# 27   36                3
# 28   37                3
# 29   38                5

# %%
y
# Out:
# 0      39343
# 1      46205
# 2      37731
# 3      43525
# 4      39891
# 5      56642
# 6      60150
# 7      54445
# 8      64445
# 9      57189
# 10     63218
# 11     55794
# 12     56957
# 13     57081
# 14     61111
# 15     67938
# 16     66029
# 17     83088
# 18     81363
# 19     93940
# 20     91738
# 21     98273
# 22    101302
# 23    113812
# 24    109431
# 25    105582
# 26    116969
# 27    112635
# 28    122391
# 29    121872
# Name: Salary, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.score(x,y)*100
# Out:
# 95.08829781612296

# %%
# y = m1x1+m2x2+c. //this is equation create.

# %%
lr.coef_
# Out:
# array([5033.41565941,  379.79037768])

# %%
lr.intercept_
# Out:
# -62162.2597865306
