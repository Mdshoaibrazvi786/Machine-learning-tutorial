# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =  pd.read_csv(r"C:\Users\mr.shoaib\Downloads\student_scores.csv")

# %%
df.head()
# Out:
#    cgpa  scores  placed
# 0  8.41      20       0
# 1  9.61      90       0
# 2  7.63      58       0
# 3  6.47      31       0
# 4  5.48       5       0

# %%
sns.kdeplot(data=df["cgpa"])
plt.show()

# %%
sns.kdeplot(data=df["scores"])
plt.show()

# %%
sns.scatterplot(x="cgpa",y="scores",data=df,hue="placed")
plt.show()

# %%
x = df.iloc[:,:-1]
y = df["placed"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB

# %%
gnb = GaussianNB()
gnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
gnb.score(x_test, y_test)*100
# Out:
# 50.0

# %%
gnb.score(x_train, y_train)*100
# Out:
# 56.25

# %%
mnb = MultinomialNB()
mnb.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
mnb.score(x_test, y_test)*100
# Out:
# 55.00000000000001

# %%
mnb.score(x_train, y_train)*100
# Out:
# 52.5

# %%
bnb=GaussianNB()
bnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
bnb.score(x_train, y_train)*100
# Out:
# 56.25

# %%
bnb.score(x_test, y_test)*100
# Out:
# 50.0
