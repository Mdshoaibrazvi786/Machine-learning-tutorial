# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel(r"C:\Users\mr.shoaib\Documents\classification.xlsx")

# %%
df
# Out:
#     data 1  data 2  output
# 0     0.03    0.99       0
# 1     2.12   -0.05       1
# 2     0.88   -0.08       0
# 3    -0.06   -0.04       1
# 4     0.83   -0.54       1
# 5     2.11    0.66       1
# 6     0.57    0.34       0
# 7     0.95   -0.75       1
# 8    -0.03    0.39       1
# 9     1.72    0.36       1
# 10   -0.28    0.61       1
# 11    2.00   -0.31       1
# 12    1.50   -0.75       1
# 13    1.23    1.20       0
# 14    0.47    0.55       0

# %%
df.isnull().sum()
# Out:
# data 1    0
# data 2    0
# output    0
# dtype: int64

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x="data 1",y="data 2",data=df,hue="output")
plt.show()

# %%
x = df.iloc[:,:-1]
y = df["output"]

# %%
x
# Out:
#     data 1  data 2
# 0     0.03    0.99
# 1     2.12   -0.05
# 2     0.88   -0.08
# 3    -0.06   -0.04
# 4     0.83   -0.54
# 5     2.11    0.66
# 6     0.57    0.34
# 7     0.95   -0.75
# 8    -0.03    0.39
# 9     1.72    0.36
# 10   -0.28    0.61
# 11    2.00   -0.31
# 12    1.50   -0.75
# 13    1.23    1.20
# 14    0.47    0.55

# %%
y
# Out:
# 0     0
# 1     1
# 2     0
# 3     1
# 4     1
# 5     1
# 6     0
# 7     1
# 8     1
# 9     1
# 10    1
# 11    1
# 12    1
# 13    0
# 14    0
# Name: output, dtype: int64

# %%
x_train,x_test,y_train,y_train = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression() 
lr.fit(x,y)
# Out:
# LogisticRegression()

# %%
lr.score(x,y)*100
# Out:
# 73.33333333333333

# %%
lr.coef_
# Out:
# array([[ 0.38103762, -0.99125659]])

# %%
lr.intercept_
# Out:
# array([0.58980825])
